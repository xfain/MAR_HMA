# %% [markdown]
# ### TO DO

# %%
import xarray as xr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from scipy.interpolate import griddata
import xesmf as xe
from pathlib import Path
import cartopy.crs as ccrs
import netCDF4  
import time

# %%
year_list = ["2003"]#,"2004","2005","2006","2007","2008","2009","2010","2011","2012","2013"]
month_list = ["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]
season_list = ["DJF","MAM","JJA","SON"]

# %%
# Domain study: Fedchenko, GRa
longitude=slice(66,78)
latitude=slice(36,42)
# temp_HMA=ds.sel(lat=lat,lon=lon)

# %% [markdown]
# #### Load MAR outputs

# %%
# MAR topography
coord = xr.open_dataset('/home/amoryc/NST.2000.01.01.00.GRa_Fedchenko.nc')
lon = coord.LON
lat = coord.LAT
H = coord.SH

# %%
# MAR dataset
folder = '/bettik/amoryc/MARout/GRf/spin3/work/'

# Surface temperature
t2m_yr = xr.open_dataset(folder+'year-TT-MARv3.14_ER5-2003-2013.nc')
t2m_mon = xr.open_dataset(folder+'mon-TT-MARv3.14_ER5-2003-2013.nc')

# Rain
wpr_yr = xr.open_dataset(folder+ 'year-RF-MARv3.14_ER5-2003-2013.nc')
wpr_mon = xr.open_dataset(folder+ 'mon-RF-MARv3.14_ER5-2003-2013.nc')

# Snow fall
spr_yr = xr.open_dataset(folder+ 'year-SF-MARv3.14_ER5-2003-2013.nc')
spr_mon = xr.open_dataset(folder+ 'mon-SF-MARv3.14_ER5-2003-2013.nc')

# Snow height
sh_yr = xr.open_dataset(folder+ 'year-SHSN3-MARv3.14_ER5-2003-2013.nc')
sh_mon = xr.open_dataset(folder+ 'mon-SHSN3-MARv3.14_ER5-2003-2013.nc')

# %% [markdown]
# ### Load Observations

# %%
# CRU, APHRODITE SNOW-CCI => Maria a déjà tout sur Spirit

# %%
# CRU : Surface mean/min/max températures, clouds
folder_cru='/bettik/PROJECTS/pr-regional-climate/observations/CRU/'

tmp_cru = xr.open_mfdataset(folder_cru + '*.tmp.dat.nc', combine='by_coords', parallel=True).sel(lat=latitude,lon=longitude).tmp.load()
tmn_cru = xr.open_mfdataset(folder_cru + '*.tmn.dat.nc', combine='by_coords', parallel=True).sel(lat=latitude,lon=longitude).tmn.load()
tmx_cru = xr.open_mfdataset(folder_cru + '*.tmx.dat.nc', combine='by_coords', parallel=True).sel(lat=latitude,lon=longitude).tmx.load()
cld_cru = xr.open_mfdataset(folder_cru + '*.cld.dat.nc', combine='by_coords', parallel=True).sel(lat=latitude,lon=longitude).cld.load()

# %%
tmx_cru.groupby("time.season").mean('time').sel(season=season_list[1]).plot()

# %% [markdown]
# ### Load ERA5

# %%
folder_era5 = '/bettik/PROJECTS/pr-regional-climate/observations/ERA5/'
ds_era5 = xr.open_mfdataset(folder_era5 + 'era5_GRa.nc')

# %%
#Open and combine all ERA5 dataset
# => better to do it with CDO.. because lack of mem

for i in range(len(year_list)):
    folder_year=year_list[i]
    path_era5_t2m = Path(folder_out_era5 + 'ds_era5_t2m_' + folder_year + '.nc')
        
    if path_era5_t2m.is_file():
        print(f'The file {path_era5_t2m} already exists')
        ds_era5_t2m = xr.open_mfdataset(folder_out_era5 + 'ds_era5_t2m_' + folder_year + '.nc', parallel=True).tas.load()
    else:
        print(f'The file {path_era5_t2m} does not exist')
        print(f'Extracting ERA5 data')
        ds_era5_t2m= xr.open_mfdataset(folder_era5 + folder_year + '/'+ file_ERA5,  combine='by_coords', parallel=True).T #concat_dim ='time',
        # ds_era5_t2m.to_netcdf(folder_out_era5 + 'ds_era5_t2m_' + folder_year + '.nc')
# Out:
# The file /bettik/fainx/MAR_HMA/forcings/ERA5/ds_era5_t2m_2003.nc does not exist
# Extracting ERA5 data

# %% [markdown]
# ### Load ERA5-Land

# %%
folder_era5_land='/bettik/PROJECTS/pr-regional-climate/observations/ERA5-land/'
ds_era5_land = xr.open_mfdataset(folder_era5_land + 'era5_land_GRa.nc')

# %% [markdown]
# ### First Plot

# %%
plt.figure(figsize=(8, 6))  
mesh = plt.pcolormesh(coord.LON, coord.LAT, t2m_yr.TT.isel(TIME=0).isel(ATMLAY=0), cmap='RdBu_r')

plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Pamir Mountains - 2003")

levels = np.arange(500, 7500, 1000)  # Niveaux tous les 1000m 
contours = plt.contour(coord.LON, coord.LAT, coord.SH, levels=levels, colors='black', linewidths=0.8)

# labels sur les courbes de niveau
plt.clabel(contours, inline=True, fontsize=8, fmt='%d m') 

cbar = plt.colorbar(mesh)
cbar.set_label("Mean annual temperature (°C)")

plt.show()
# Out:
# /tmp/ipykernel_2336041/2406091145.py:2: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   mesh = plt.pcolormesh(coord.LON, coord.LAT, t2m_yr.TT.isel(TIME=0).isel(ATMLAY=0), cmap='RdBu_r')

# %%
years = np.arange(2003, 2013) #2013 dataset not shown

fig, axes = plt.subplots(2, 5, figsize=(15, 6), sharex=True, sharey=True)

for i, ax in enumerate(axes.flat):
    mesh = ax.pcolormesh(coord.LON, coord.LAT, t2m_yr.TT.isel(TIME=i).isel(ATMLAY=0), cmap='RdBu_r', shading='auto')
    
    levels = np.arange(500, 7500, 1000)  # Niveaux tous les 1000m
    contours = ax.contour(coord.LON, coord.LAT, coord.SH, levels=levels, colors='black', linewidths=0.8)
    ax.clabel(contours, inline=True, fontsize=6, fmt='%d m')

    ax.set_title(f"{years[i]}", fontsize=10)

    # Axes (seulement pour les bords)
    if i % 5 == 0:
        ax.set_ylabel("Latitude")
    if i >= 5:
        ax.set_xlabel("Longitude")


cbar = fig.colorbar(mesh, ax=axes, orientation='horizontal', fraction=0.05, pad=0.1)
cbar.set_label("Temperature (°C)")

# Ajustement des espacements
plt.tight_layout()

plt.show()
# Out:
# /tmp/ipykernel_2336041/3039237409.py:6: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   mesh = ax.pcolormesh(coord.LON, coord.LAT, t2m_yr.TT.isel(TIME=i).isel(ATMLAY=0), cmap='RdBu_r', shading='auto')
# /tmp/ipykernel_2336041/3039237409.py:25: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# # Seasonnal variability

# %% [markdown]
# ## Surface Temperature

# %% [markdown]
# #### Add comparison with CRU, ERA5, including differences (MAR-CRU..)

# %%
#A travailler : interpolation entre grilles lat/lon et MAR

t2m_mon_regrid = t2m_mon.TT.isel(ATMLAY=0).interp(lat=tmx_cru['lat'], lon = tmx_cru['lon'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 t2m_mon_regrid = t2m_mon.TT.isel(ATMLAY=0).interp(lat=tmx_cru['lat'], lon = tmx_cru['lon'])
#
# File ~/micromamba/envs/xav_2412/lib/python3.11/site-packages/xarray/core/dataarray.py:2383, in DataArray.interp(self, coords, method, assume_sorted, kwargs, **coords_kwargs)
#    2379 if self.dtype.kind not in "uifc":
#    2380     raise TypeError(
#    2381         f"interp only works for a numeric type array. Given {self.dtype}."
#    2382     )
# -> 2383 ds = self._to_temp_dataset().interp(
#    2384     coords,
#    2385     method=method,
#    2386     kwargs=kwargs,
#    2387     assume_sorted=assume_sorted,
#    2388     **coords_kwargs,
#    2389 )
#    2390 return self._from_temp_dataset(ds)
#
# File ~/micromamba/envs/xav_2412/lib/python3.11/site-packages/xarray/core/dataset.py:4126, in Dataset.interp(self, coords, method, assume_sorted, kwargs, method_non_numeric, **coords_kwargs)
#    4123     kwargs = {}
#    4125 coords = either_dict_or_kwargs(coords, coords_kwargs, "interp")
# -> 4126 indexers = dict(self._validate_interp_indexers(coords))
#    4128 if coords:
#    4129     # This avoids broadcasting over coordinates that are both in
#    4130     # the original array AND in the indexing array. It essentially
#    4131     # forces interpolation along the shared coordinates.
#    4132     sdims = (
#    4133         set(self.dims)
#    4134         .intersection(*[set(nx.dims) for nx in indexers.values()])
#    4135         .difference(coords.keys())
#    4136     )
#
# File ~/micromamba/envs/xav_2412/lib/python3.11/site-packages/xarray/core/dataset.py:2921, in Dataset._validate_interp_indexers(self, indexers)
#    2917 def _validate_interp_indexers(
#    2918     self, indexers: Mapping[Any, Any]
#    2919 ) -> Iterator[tuple[Hashable, Variable]]:
#    2920     """Variant of _validate_indexers to be used for interpolation"""
# -> 2921     for k, v in self._validate_indexers(indexers):
#    2922         if isinstance(v, Variable):
#    2923             if v.ndim == 1:
#
# File ~/micromamba/envs/xav_2412/lib/python3.11/site-packages/xarray/core/dataset.py:2885, in Dataset._validate_indexers(self, indexers, missing_dims)
#    2882 from xarray.coding.cftimeindex import CFTimeIndex
#    2883 from xarray.core.dataarray import DataArray
# -> 2885 indexers = drop_dims_from_indexers(indexers, self.dims, missing_dims)
#    2887 # all indexers should be int, slice, np.ndarrays, or Variable
#    2888 for k, v in indexers.items():
#
# File ~/micromamba/envs/xav_2412/lib/python3.11/site-packages/xarray/core/utils.py:802, in drop_dims_from_indexers(indexers, dims, missing_dims)
#     800     invalid = indexers.keys() - set(dims)
#     801     if invalid:
# --> 802         raise ValueError(
#     803             f"Dimensions {invalid} do not exist. Expected one or more of {dims}"
#     804         )
#     806     return indexers
#     808 elif missing_dims == "warn":
#     809     # don't modify input
#
# ValueError: Dimensions {'lon', 'lat'} do not exist. Expected one or more of FrozenMappingWarningOnValuesAccess({'TIME': 132, 'X': 164, 'Y': 116})

# %%
nrows=4
ncols=3



fig, axes = plt.subplots(nrows=nrows, ncols=ncols, sharex=True, sharey=True, figsize=(10, 14)) 
j=0
k=0

column_titles = ["MAR", "CRU", "Difference MAR - CRU"]
row_titles = season_list


for i, ax in enumerate(axes.flat):
    if (i) % 3 == 0 : 
        m = ax.pcolormesh(coord.LON, coord.LAT,t2m_mon.TT.isel(ATMLAY=0).groupby("TIME.season").mean('TIME').sel(season=season_list[j]), cmap='RdBu_r', shading='auto',  vmin=-20, vmax=20)
        j=j+1
    elif (i-1) % 3 == 0 : 
         m = ax.pcolormesh(tmx_cru['lon'], tmx_cru['lat'],tmx_cru.groupby("time.season").mean('time').sel(season=season_list[k]), cmap='RdBu_r', shading='auto',  vmin=-20, vmax=20)
         k=k+1
        
        
    levels = np.arange(500, 7500, 1000)  # Niveaux tous les 1000m
    contours = ax.contour(coord.LON, coord.LAT, coord.SH, levels=levels, colors='black', linewidths=0.8)
    ax.clabel(contours, inline=True, fontsize=6, fmt='%d m')

for col in range(ncols):
    axes[0, col].set_title(column_titles[col], fontsize=12, fontweight='bold')
for row in range(nrows):
    fig.text(0.02, 0.78 - row * 0.22, row_titles[row], fontsize=12, fontweight='bold', rotation=90, va='center')

    
fig.suptitle('Mean seasonnal (2003-2014) surface temperature : MAR vs CRU', fontsize=12)

cbar_ax = fig.add_axes([1, 0.15, 0.03, 0.7]) 
fig.colorbar(mesh, cax=cbar_ax, orientation='vertical', label='Temperature (°C)')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3922576/3120677813.py:16: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   m = ax.pcolormesh(coord.LON, coord.LAT,t2m_mon.TT.isel(ATMLAY=0).groupby("TIME.season").mean('TIME').sel(season=season_list[j]), cmap='RdBu_r', shading='auto',  vmin=-20, vmax=20)
# /tmp/ipykernel_3922576/3120677813.py:16: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   m = ax.pcolormesh(coord.LON, coord.LAT,t2m_mon.TT.isel(ATMLAY=0).groupby("TIME.season").mean('TIME').sel(season=season_list[j]), cmap='RdBu_r', shading='auto',  vmin=-20, vmax=20)
# /tmp/ipykernel_3922576/3120677813.py:16: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   m = ax.pcolormesh(coord.LON, coord.LAT,t2m_mon.TT.isel(ATMLAY=0).groupby("TIME.season").mean('TIME').sel(season=season_list[j]), cmap='RdBu_r', shading='auto',  vmin=-20, vmax=20)
# /tmp/ipykernel_3922576/3120677813.py:16: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   m = ax.pcolormesh(coord.LON, coord.LAT,t2m_mon.TT.isel(ATMLAY=0).groupby("TIME.season").mean('TIME').sel(season=season_list[j]), cmap='RdBu_r', shading='auto',  vmin=-20, vmax=20)
# /tmp/ipykernel_3922576/3120677813.py:36: UserWarning: Adding colorbar to a different Figure <Figure size 640x480 with 12 Axes> than <Figure size 1000x1400 with 13 Axes> which fig.colorbar is called on.
#   fig.colorbar(mesh, cax=cbar_ax, orientation='vertical', label='Temperature (°C)')
# /tmp/ipykernel_3922576/3120677813.py:38: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# #### Comparing MAR and ERA5-LAND

# %%
nrows=4
ncols=3

fig, axes = plt.subplots(nrows=nrows, ncols=ncols, sharex=True, sharey=True, figsize=(10, 14)) 
j=0
k=0

for i, ax in enumerate(axes.flat):
    if (i) % 3 == 0 : 
        m = ax.pcolormesh(coord.LON, coord.LAT,t2m_mon.TT.isel(ATMLAY=0).groupby("TIME.season").mean('TIME').sel(season=season_list[j]), cmap='RdBu_r', shading='auto',  vmin=-20, vmax=20)
        j=j+1
    elif (i-1) % 3 == 0 : 
         m = ax.pcolormesh(ds_era5_land['longitude'], ds_era5_land['latitude'], ds_era5_land.t2m.groupby("valid_time.season").mean('valid_time').sel(season=season_list[k])-273.15, cmap='RdBu_r', shading='auto',  vmin=-20, vmax=20)
         k=k+1
        
# ds_era5.t.isel(valid_time=1).isel(pressure_level=0).plot()
    levels = np.arange(500, 7500, 1000)  # Niveaux tous les 1000m
    contours = ax.contour(coord.LON, coord.LAT, coord.SH, levels=levels, colors='black', linewidths=0.8)
    ax.clabel(contours, inline=True, fontsize=6, fmt='%d m')
    
fig.suptitle('Mean seasonnal (2003-2014) temperature : MAR vs ERA5-LAND', fontsize=12)

cbar_ax = fig.add_axes([1, 0.15, 0.03, 0.7]) 
fig.colorbar(mesh, cax=cbar_ax, orientation='vertical', label='Temperature (°C)')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3922576/2489684343.py:10: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   m = ax.pcolormesh(coord.LON, coord.LAT,t2m_mon.TT.isel(ATMLAY=0).groupby("TIME.season").mean('TIME').sel(season=season_list[j]), cmap='RdBu_r', shading='auto',  vmin=-20, vmax=20)
# /tmp/ipykernel_3922576/2489684343.py:10: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   m = ax.pcolormesh(coord.LON, coord.LAT,t2m_mon.TT.isel(ATMLAY=0).groupby("TIME.season").mean('TIME').sel(season=season_list[j]), cmap='RdBu_r', shading='auto',  vmin=-20, vmax=20)
# /tmp/ipykernel_3922576/2489684343.py:10: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   m = ax.pcolormesh(coord.LON, coord.LAT,t2m_mon.TT.isel(ATMLAY=0).groupby("TIME.season").mean('TIME').sel(season=season_list[j]), cmap='RdBu_r', shading='auto',  vmin=-20, vmax=20)
# /tmp/ipykernel_3922576/2489684343.py:10: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   m = ax.pcolormesh(coord.LON, coord.LAT,t2m_mon.TT.isel(ATMLAY=0).groupby("TIME.season").mean('TIME').sel(season=season_list[j]), cmap='RdBu_r', shading='auto',  vmin=-20, vmax=20)
# /tmp/ipykernel_3922576/2489684343.py:24: UserWarning: Adding colorbar to a different Figure <Figure size 640x480 with 12 Axes> than <Figure size 1000x1400 with 13 Axes> which fig.colorbar is called on.
#   fig.colorbar(mesh, cax=cbar_ax, orientation='vertical', label='Temperature (°C)')
# /tmp/ipykernel_3922576/2489684343.py:26: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# #### Comparing MAR and ERA5

# %%
#Vérifier le sens de 'pressure_level'

nrows=4
ncols=3

fig, axes = plt.subplots(nrows=nrows, ncols=ncols, sharex=True, sharey=True, figsize=(10, 14)) 
j=0
k=0

for i, ax in enumerate(axes.flat):
    if (i) % 3 == 0 : 
        m = ax.pcolormesh(coord.LON, coord.LAT,t2m_mon.TT.isel(ATMLAY=0).groupby("TIME.season").mean('TIME').sel(season=season_list[j]), cmap='RdBu_r', shading='auto',  vmin=-20, vmax=20)
        j=j+1
    elif (i-1) % 3 == 0 : 
         m = ax.pcolormesh(ds_era5['longitude'], ds_era5['latitude'], ds_era5.t.isel(pressure_level=10).groupby("valid_time.season").mean('valid_time').sel(season=season_list[k])-273.15, cmap='RdBu_r', shading='auto',  vmin=-20, vmax=20)
         k=k+1
        
# ds_era5.t.isel(valid_time=1).isel(pressure_level=0).plot()
    levels = np.arange(500, 7500, 1000)  # Niveaux tous les 1000m
    contours = ax.contour(coord.LON, coord.LAT, coord.SH, levels=levels, colors='black', linewidths=0.8)
    ax.clabel(contours, inline=True, fontsize=6, fmt='%d m')
    
fig.suptitle('Mean seasonnal (2003-2014) temperature : MAR vs ERA5', fontsize=12)

cbar_ax = fig.add_axes([1, 0.15, 0.03, 0.7]) 
fig.colorbar(mesh, cax=cbar_ax, orientation='vertical', label='Temperature (°C)')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3922576/1986612807.py:12: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   m = ax.pcolormesh(coord.LON, coord.LAT,t2m_mon.TT.isel(ATMLAY=0).groupby("TIME.season").mean('TIME').sel(season=season_list[j]), cmap='RdBu_r', shading='auto',  vmin=-20, vmax=20)
# /tmp/ipykernel_3922576/1986612807.py:12: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   m = ax.pcolormesh(coord.LON, coord.LAT,t2m_mon.TT.isel(ATMLAY=0).groupby("TIME.season").mean('TIME').sel(season=season_list[j]), cmap='RdBu_r', shading='auto',  vmin=-20, vmax=20)
# /tmp/ipykernel_3922576/1986612807.py:12: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   m = ax.pcolormesh(coord.LON, coord.LAT,t2m_mon.TT.isel(ATMLAY=0).groupby("TIME.season").mean('TIME').sel(season=season_list[j]), cmap='RdBu_r', shading='auto',  vmin=-20, vmax=20)
# /tmp/ipykernel_3922576/1986612807.py:12: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   m = ax.pcolormesh(coord.LON, coord.LAT,t2m_mon.TT.isel(ATMLAY=0).groupby("TIME.season").mean('TIME').sel(season=season_list[j]), cmap='RdBu_r', shading='auto',  vmin=-20, vmax=20)
# /tmp/ipykernel_3922576/1986612807.py:26: UserWarning: Adding colorbar to a different Figure <Figure size 640x480 with 12 Axes> than <Figure size 1000x1400 with 13 Axes> which fig.colorbar is called on.
#   fig.colorbar(mesh, cax=cbar_ax, orientation='vertical', label='Temperature (°C)')
# /tmp/ipykernel_3922576/1986612807.py:28: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
#Ajouter une dépendance à l'altitude

nrows=1
ncols=3

fig, ax = plt.subplots(nrows=nrows, ncols=ncols,  figsize=(14, 4)) 

ax[0].plot(t2m_mon.TT.isel(ATMLAY=0).groupby('TIME.month').mean('TIME').mean(('X', 'Y')),marker='o', linestyle='-')

ax[0].set_xticks(np.arange(0, 12))
ax[0].set_xticklabels(month_list)

ax[0].set_xlabel("Month")
ax[0].set_ylabel("Temperature (°C)")
ax[0].set_title("Mean (2003-2014) Temperature")
ax[0].grid(True, linestyle="--", linewidth=0.5, alpha=0.7)

ax[1].plot(spr_mon.SF.groupby('TIME.month').mean('TIME').mean(('X', 'Y')),marker='o', linestyle='-', color = 'r')

ax[1].set_xticks(np.arange(0, 12))
ax[1].set_xticklabels(month_list)

ax[1].set_xlabel("Month")
ax[1].set_ylabel("Snow Fall (mmWE/day)")
ax[1].set_title("Mean (2003-2014) Snow Fall")
ax[1].grid(True, linestyle="--", linewidth=0.5, alpha=0.7)

ax[2].plot(wpr_mon.RF.groupby('TIME.month').mean('TIME').mean(('X', 'Y')),marker='o', linestyle='-', color = 'g')

ax[2].set_xticks(np.arange(0, 12))
ax[2].set_xticklabels(month_list)

ax[2].set_xlabel("Month")
ax[2].set_ylabel("Rain (mm/day)")
ax[2].set_title("Mean (2003-2014) rain precipitation")
ax[2].grid(True, linestyle="--", linewidth=0.5, alpha=0.7)

plt.show()

# %% [markdown]
# ## Snow Pack Characteristics

# %% [markdown]
# ##### Need to include comparison with SNOW-CCI

# %%
nrows=4
ncols=1

fig, axes = plt.subplots(nrows=nrows, ncols=ncols, sharex=True, sharey=True, figsize=(4, 14)) 

for i, ax in enumerate(axes.flat):
    mesh = ax.pcolormesh(coord.LON, coord.LAT,sh_mon.SHSN3.groupby("TIME.season").mean('TIME').isel(SECTOR=1).sel(season=season_list[i]), shading='auto',  vmin=0, vmax=8)
    
    levels = np.arange(500, 7500, 1000)  # Niveaux tous les 1000m
    contours = ax.contour(coord.LON, coord.LAT, coord.SH, levels=levels, colors='black', linewidths=0.8)
    ax.clabel(contours, inline=True, fontsize=6, fmt='%d m')
    
    ax.set_title(season_list[i]) 
    ax.set_ylabel('Latitude') 
    # if i % 5 == 0:
    #     axs[i].set_ylabel("Latitude")
    if i >= 3:
        ax.set_xlabel("Longitude")

fig.suptitle('Mean (2003-2014) Snow pack height', fontsize=16)

cbar_ax = fig.add_axes([1, 0.15, 0.03, 0.7]) 
fig.colorbar(mesh, cax=cbar_ax, orientation='vertical', label='Snow pack height (m)')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2336041/1796893423.py:7: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   mesh = ax.pcolormesh(coord.LON, coord.LAT,sh_mon.SHSN3.groupby("TIME.season").mean('TIME').isel(SECTOR=1).sel(season=season_list[i]), shading='auto',  vmin=0, vmax=8)
# /tmp/ipykernel_2336041/1796893423.py:7: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   mesh = ax.pcolormesh(coord.LON, coord.LAT,sh_mon.SHSN3.groupby("TIME.season").mean('TIME').isel(SECTOR=1).sel(season=season_list[i]), shading='auto',  vmin=0, vmax=8)
# /tmp/ipykernel_2336041/1796893423.py:7: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   mesh = ax.pcolormesh(coord.LON, coord.LAT,sh_mon.SHSN3.groupby("TIME.season").mean('TIME').isel(SECTOR=1).sel(season=season_list[i]), shading='auto',  vmin=0, vmax=8)
# /tmp/ipykernel_2336041/1796893423.py:7: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   mesh = ax.pcolormesh(coord.LON, coord.LAT,sh_mon.SHSN3.groupby("TIME.season").mean('TIME').isel(SECTOR=1).sel(season=season_list[i]), shading='auto',  vmin=0, vmax=8)
# /tmp/ipykernel_2336041/1796893423.py:25: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
1+1
# Out:
# 2
