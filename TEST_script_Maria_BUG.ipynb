# %%
import sys
sys.path.insert(1, '/home/fainx/MyPythonLibrary/MAR-RECAP/libmar/')
import climbasis as climb
from climbasis import *
import domain as dom
import myplot
import numpy.ma as ma
from myplot import *
import obsinfo as obs
from obsinfo import *
from scipy.stats import pearsonr

# %%
iyr=2000
fyr=2023
domain='FEDMAR'
latS,latN,lonW,lonE,latlim,lonlim=dom.coord_domain(domain)  
print(latS,latN,lonW,lonE)
variable='t2m'
var='t2m'
units='°C'
exp='obs'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 4
#       2 fyr=2023
#       3 domain='FEDMAR'
# ----> 4 latS,latN,lonW,lonE,latlim,lonlim=dom.coord_domain(domain)
#       5 print(latS,latN,lonW,lonE)
#       6 variable='t2m'
#
# File ~/MyPythonLibrary/MAR-RECAP/libmar/domain.py:288, in coord_domain(domain)
#     286     lonlim=slice(lonW,lonE)
#     287 else:
# --> 288     raise ValueError(
#     289         f"""Invalid zone argument. Valid zones are:
#     290             - 'GLOB', 'global', 'GLOBAL'
#     291             - 'NH' : North Hemisphere
#     292             - 'HMA' : High Mountain of Asia
#     293             - 'NA' : North America
#     294          """
#     295     )
#     296 return latS,latN,lonW,lonE,latlim,lonlim
#
# ValueError: Invalid zone argument. Valid zones are:
#                 - 'GLOB', 'global', 'GLOBAL'
#                 - 'NH' : North Hemisphere
#                 - 'HMA' : High Mountain of Asia
#                 - 'NA' : North America
